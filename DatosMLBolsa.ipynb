# %%
# Para obtener los datos vamos a utilizar pandas_datareader (https://pandas-datareader.readthedocs.io/)
from pandas_datareader import data

# %%
# Definimos tickers en los cuales estamos interesados
# Algunas empresas del S&P500
tickers = ['ADP', ]

# Definimos el rango de fechas deseado
start_date = '2020-01-01'
end_date = '2020-12-31'

# Obtenemos un DataFrame
df = data.DataReader(
    tickers, 
    start=start_date, 
    end=end_date, 
    data_source='yahoo',
)

# %%
df
# Out:
# Attributes   Adj Close       Close        High         Low        Open  \
# Symbols            ADP         ADP         ADP         ADP         ADP
# Date
# 2020-01-02  165.426331  170.320007  172.000000  169.199997  171.960007
# 2020-01-03  165.076660  169.960007  170.449997  168.059998  168.059998
# 2020-01-06  165.300064  170.190002  170.339996  168.830002  169.080002
# 2020-01-07  163.299271  168.130005  169.460007  167.949997  169.289993
# 2020-01-08  164.833862  169.710007  170.509995  168.169998  168.789993
# ...                ...         ...         ...         ...         ...
# 2020-12-24  175.658142  176.559998  176.570007  174.929993  176.119995
# 2020-12-28  175.707886  176.610001  178.160004  176.470001  177.550003
# 2020-12-29  173.976776  174.869995  177.809998  174.570007  177.460007
# 2020-12-30  172.922180  173.809998  176.250000  173.320007  175.600006
# 2020-12-31  175.299973  176.199997  176.449997  173.330002  174.139999
#
# Attributes     Volume
# Symbols           ADP
# Date
# 2020-01-02  1364600.0
# 2020-01-03  1000100.0
# 2020-01-06  1205900.0
# 2020-01-07  1878900.0
# 2020-01-08  1675500.0
# ...               ...
# 2020-12-24   371600.0
# 2020-12-28   770500.0
# 2020-12-29   797100.0
# 2020-12-30   787500.0
# 2020-12-31  1142800.0
#
# [253 rows x 6 columns]
